# %%
import scanpy as sc
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

sc.settings.verbosity = 3
sc.settings.set_figure_params(dpi=100, facecolor="white")

# %% [markdown]
# Load .h5ad

# %%
adata = sc.read_h5ad("../data/processed/abc_atlas/expression_matrices/WHB-10Xv3/20240330/WHB-10Xv3-Nonneurons-log2.h5ad")
adata
# Out:
# AnnData object with n_obs × n_vars = 888263 × 59357
#     obs: 'cell_barcode', 'library_label', 'anatomical_division_label'
#     var: 'gene_symbol'

# %%
adata.obs.head()
adata.var.head()
adata.obs.columns
adata.var_names[:10]

# %% [markdown]
# ## First Milestone
# Load a brain single-cell dataset and produce a UMAP colored by known or inferred cell types.
